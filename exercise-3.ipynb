# %%
library(xlsx)
library(ggplot2)
library(dplyr) # for renaming columns
library(reshape2)
library(tidyr)

# %%
df = read.xlsx2("QualidadeARO3.xlsx", sheetName = "Sheet1")
df <- type.convert(df, as.is = TRUE)
df <- df[, c("Paio.Pires", "VNTelha.Maia")]
aux_df <- pivot_longer(df, Paio.Pires:VNTelha.Maia)
aux_df <- rename(aux_df, Estações = name)

# %%
# histogram plotting how many times a given value appears in the column "value" with ggplot
ggplot(aux_df, aes(x = value, fill = Estações)) + 
  geom_histogram(binwidth = 4, position = position_dodge()) +
  theme_minimal() +
  scale_x_continuous(breaks = round(seq(from = 0, to = 200, by = 10),5)) +
  scale_y_continuous(breaks = round(seq(from = 0, to = 1000, by = 20),5)) +
  labs(x = "Valor (Nível de Ozono)", y = "Frequência") +
  ggtitle("Frequência dos valores de Ozono em Paio Pires e VNTelha Maia em 2020")
# Out:
# plot without title
